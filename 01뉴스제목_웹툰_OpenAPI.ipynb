# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
# BeautifulSoup import
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# sid = 105
# url = 'https://news.naver.com/section/{sid}'
url = 'https://news.naver.com/section/{sid}'.format(**req_param) #딕셔너리를 넘겨주는 경우 **을 앞에 붙여줌
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

# requests 의 get() 함수 호출하기 
res=requests.get(url, headers=req_header)
print(res.status_code, res.ok)
print(type(res))
print(res)
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
if (res.ok):
    html = res.text
    print(html)
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")
    print(soup)
    # CSS 선택자
    # # print(soup.select("div.sa_text a[href*='mnews/article']"))
    a_tags = soup.select("div.sa_text a[href*='mnews/article'].sa_text_title")
    print(len(a_tags))
    print(type(a_tags))
    # <a> 태그 리스트 순회하기   
    for idx, a_tag in enumerate(a_tags,1):
        if a_tag.text:
            title = a_tag.text.strip() # 제목
            link = a_tag['href'] # 링크
            # print(len(title))
            print(f'{idx} {title} {link}')
else:
    # 응답(response)이 Error 이면 status code 출력  
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# <class 'requests.models.Response'>
# <Response [200]>
# <!doctype html>
# <html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="referrer" contents="always">
# 		<meta http-equiv="refresh" content="600">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="IT/과학 : 네이버 뉴스">
# 		<meta property="og:type" content="website">
# 		<meta property="og:url" content="https://news.naver.com/section/105">
# 		<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta property="og:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">
# 		<meta property="og:article:author" content="네이버">
# 		<meta name="twitter:card" content="summary">
# 		<meta name="twitter:title" content="IT/과학 : 네이버 뉴스">
# 		<meta name="twitter:site" content="네이버 뉴스">
# 		<meta name="twitter:creator" content="네이버 뉴스">
# 		<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta name="twitter:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">
# 		<title>IT/과학 : 네이버 뉴스</title>
# 			<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20250717/news.css">
# 			<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />
# 			<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 			<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />
# 			<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />
# 			<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />
# 			<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 					<script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# 		<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# 				<script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "itn";
#
# 			var svr = "one-service-r-20250717-250717-162549-8dfcd689-gl68g";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "105";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# 		<script src="https://static-nnews.pstatic.net/js/min/20250717/common.min.js"></script>
# 	</head>
# 	<body class="n_news_mnews fs1 as_mp_layout as_section_home">
# 		<div class="end_container">
# 		<div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# 		<header role="banner" class="as_gnb_mnews as_type_section">
# 	<div class="header_inner">
# 		<div class="Ngnb">
# 			<div class="Ngnb_inner">
# 				<div class="Ngnb_both">
# 					<div class="Ngnb_left">
# 						<span class="Ngnb_logo"><a href="https://m.naver.com/" class="Nlogo_link _LINK" data-clk="gnb.naver" data-url="https://m.naver.com/" data-pc-url="https://www.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# 						<div class="Ngnb_service">
# 							<h1 class="Nservice_item"><a href="https://m.news.naver.com" class="_LINK" data-clk="gnb.news" data-url="https://m.news.naver.com" data-pc-url="https://news.naver.com/"><span class="Nicon_service">뉴스</span></a></h1>
# 							<span class="Nservice_subitem">
# 								<a href="https://m.entertain.naver.com" class="_LINK" data-clk="gnb.entertain" data-url="https://m.entertain.naver.com" data-pc-url="https://entertain.naver.com/home">
# 									<span class="Nicon_family Nicon_entertain">엔터</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://m.sports.naver.com" class="_LINK" data-clk="gnb.sports" data-url="https://m.sports.naver.com" data-pc-url="https://sports.news.naver.com/index">
# 									<span class="Nicon_family Nicon_sports">스포츠</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://weather.naver.com" data-clk="gnb.weather">
# 									<span class="Nicon_family Nicon_weather">날씨</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://contents.premium.naver.com" data-clk="gnb.premium">
# 									<span class="Nicon_family Nicon_premium">프리미엄</span>
# 								</a>
# 							</span>
# 						</div>
# 					</div>
# 					<div class="Ngnb_right">
# 						<div class="Ngnb_group">
# 							<div id="gnb" class="gnb_dark_type2"></div>
# 						</div>
# 						<div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# 						<div class="Ngnb_tool">
# 							<a href="javascript:;" class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho"><span class="Nicon_search">검색</span></a>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="_LNB_PARENT_WRAP" class="Nlnb" style="z-index:3000;" data-scroll-fixed="true">
# 		<div id="_LNB_WRAP" class="Nlnb_menu Ntype_scroll ">
# 			<div id="_LNB" class="Nlnb_menu_inner">
# 				<ul class="Nlnb_menu_list" role="tablist">
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.press"><span class="Nitem_link_menu">언론사별</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/100" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.pol"><span class="Nitem_link_menu">정치</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/101" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.eco"><span class="Nitem_link_menu">경제</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/102" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.soc"><span class="Nitem_link_menu">사회</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/103" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.lif"><span class="Nitem_link_menu">생활/문화</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# 						<a href="https://news.naver.com/section/105" class="Nitem_link" role="tab" aria-selected="true" data-clk="lnb.it"><span class="Nitem_link_menu">IT/과학</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/104" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.wor"><span class="Nitem_link_menu">세계</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/ranking/popularDay.naver?mid&#x3D;etc&amp;sid1&#x3D;111" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.rank"><span class="Nitem_link_menu">랭킹</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/newspaper/home" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.paper"><span class="Nitem_link_menu">신문보기</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/opinion/home.naver" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.opi"><span class="Nitem_link_menu">오피니언</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/tv/index.naver?mid&#x3D;tvh" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.tv"><span class="Nitem_link_menu">TV</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/factcheck/main.naver" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.fact"><span class="Nitem_link_menu">팩트체크</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://media.naver.com/algorithm" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.algo"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/ombudsman/errorArticleList" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.correct"><span class="Nitem_link_menu">정정보도 모음</span></a>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 		</div>
# 	</div>
# </header>
# <hr>
# <script>
# 	var svt = "20250723104543.995";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
#
# 	var isDegradeMode = false;
# 	var isDegradeN2Mode = false;
# </script>
# <div id="ct_wrap" class="ct_wrap">
# 	<div class="ct_lnb">
# 		<div class="ct_lnb_inner">
# 			<strong class="ct_lnb_date">07.23(수)</strong>
# 			<ul class="ct_lnb_side">
# 				<li class="ct_lnb_side_item">
# 					<a href="https://news.naver.com/main/officeList.naver" class="ct_lnb_side_link" data-clk="slb.allmedia">전체 언론사</a>
# 				</li>
# 				<li class="ct_lnb_side_item">
# 					<a href="https://newsstand.naver.com/" class="ct_lnb_side_link" target="_blank" data-clk="slb.newsstand">뉴스스탠드</a>
# 				</li>
# 				<li class="ct_lnb_side_item">
# 					<a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="ct_lnb_side_link" target="_blank" data-clk="slb.library">라이브러리</a>
# 				</li>
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="ct_scroll_wrapper">
# 		<div class="column0">
# 			<div class="ct_snb">
# 				<h2 class="ct_snb_h2">
# 					<a href="/section/105" class="ct_snb_h2_a" data-clk="lmn_itn.home">IT/과학</a>
# 				</h2>
# 				<ul class="ct_snb_nav">
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/731" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="1">모바일</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/226" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="2">인터넷/SNS</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/227" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="3">통신/뉴미디어</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/230" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="4">IT 일반</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/732" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="5">보안/해킹</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/283" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="6">컴퓨터</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/229" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="7">게임/리뷰</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/228" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="8">과학 일반</a>
# 					</li>
# 				</ul>
# 				<div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# 					<a href="https://media.naver.com/algorithm" data-clk="lmn_itn.pmb" data-rank="1">
# 						<img data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" width="71" height="74" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" alt="AI 뉴스 알고리즘 안내" style="display: none;">
# 					</a>
# 				</div>
# 				<div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# 					<a href="https://contents.premium.naver.com/" data-clk="lmn_itn.pmb" data-rank="2">
# 						<img data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71" height="74" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" alt="프리미엄콘텐츠" style="display: none;">
# 					</a>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="newsct" class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# 	<div class="sa_head">
# 		<span class="sa_head_inner">
# 			<a href="#" class="sa_head_link _TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_rf9ot" data-clk="guide">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# 		</span>
# 		<div id="_SECTION_HEADLINE_INFO_rf9ot" class="sa_head_layer is_hidden">
# 			<p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>
# 			<a href="https://media.naver.com/algorithm" class="sa_head_layer_go">알고리즘 자세히 보기</a>
# 			<div class="sa_head_layer_close">
# 				<button type="button" class="_TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_rf9ot">닫기</button>
# 			</div>
# 		</div>
# 	</div>
# 	<ul id="_SECTION_HEADLINE_LIST_rf9ot" class="sa_list">
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/018/0006071842" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000006071842" data-imp-url="https://n.news.naver.com/mnews/article/018/0006071842" data-imp-index="1">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/018/2025/07/23/6071842.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="KT그룹, 수해 복구 성금 10억원 기탁" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/018/0006071842" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000006071842" data-imp-url="https://n.news.naver.com/mnews/article/018/0006071842" data-imp-index="1">
# 							<strong class="sa_text_strong">KT그룹, 수해 복구 성금 10억원 기탁</strong>
# 						</a>
# 						<div class="sa_text_lede">KT(030200)그룹이 기록적인 집중호우로 큰 피해를 입은 수해 지역 주민들을 돕기 위해 사회복지공동모금회(사랑의열매)에 수해 복구 성금 10억원을 기탁했다고 23일 밝혔다. 이번 성금은 피해 주민들의 일상 복귀와</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">이데일리</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/018/0006071842" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news018,0006071842" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507220820_00000002/section/105?oid&#x3D;018&amp;aid&#x3D;0006071842" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">18</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/021/0002724449" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C4_000000000000000002724449" data-imp-url="https://n.news.naver.com/mnews/article/021/0002724449" data-imp-index="2">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/021/2025/07/22/2724449.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="단통법 오늘 폐지…‘마이너스폰’ ‘페이백’ 가능 고객은 신난다" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/021/0002724449" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C4_000000000000000002724449" data-imp-url="https://n.news.naver.com/mnews/article/021/0002724449" data-imp-index="2">
# 							<strong class="sa_text_strong">단통법 오늘 폐지…‘마이너스폰’ ‘페이백’ 가능 고객은 신난다</strong>
# 						</a>
# 						<div class="sa_text_lede">방송통신위원회와 과학기술정보통신부 등 관계부처에서 ‘이동통신단말장치 유통구조 개선에 관한 법률’(단통법) 폐지 시행·주요 제도 변경사항 시행을 하루 앞둔 21일 서울 시내 한 휴대폰 판매점에 단말기와 관련해 홍보물이</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">문화일보</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/021/0002724449" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news021,0002724449" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507161600_00001473/section/105?oid&#x3D;021&amp;aid&#x3D;0002724449" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">59</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/009/0005529568" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000BC_000000000000000005529568" data-imp-url="https://n.news.naver.com/mnews/article/009/0005529568" data-imp-index="3">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/009/2025/07/23/5529568.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="CJ ENM, 韓 엔터사 최초 사우디에 법인 설립" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/009/0005529568" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000BC_000000000000000005529568" data-imp-url="https://n.news.naver.com/mnews/article/009/0005529568" data-imp-index="3">
# 							<strong class="sa_text_strong">CJ ENM, 韓 엔터사 최초 사우디에 법인 설립</strong>
# 						</a>
# 						<div class="sa_text_lede">CJ ENM이 사우디아라비아에 현지 법인을 세웠다. 23일 CJ ENM에 따르면, 사우디아라비아 리야드에 중동 법인 ‘CJ ENM 미들 이스트’(CJ ENM Middle East)를 설립했다. 국내 엔터테인먼트 기업</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">매일경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/009/0005529568" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news009,0005529568" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507220950_00000012/section/105?oid&#x3D;009&amp;aid&#x3D;0005529568" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">21</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/421/0008386752" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008386752" data-imp-url="https://n.news.naver.com/mnews/article/421/0008386752" data-imp-index="4">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/421/2025/07/23/8386752.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="노벨화학상 숨은 주역…APEC 우수 신진연구자 상에 백민경 교수" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/421/0008386752" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008386752" data-imp-url="https://n.news.naver.com/mnews/article/421/0008386752" data-imp-index="4">
# 							<strong class="sa_text_strong">노벨화학상 숨은 주역…APEC 우수 신진연구자 상에 백민경 교수</strong>
# 						</a>
# 						<div class="sa_text_lede">올해 아시아태평양경제협력체(APEC) 역내 우수 신진연구자로 백민경 서울대 교수가 선정됐다. 그는 지난해 노벨화학상을 받은 데이비드 베이커 워싱턴대 교수와 함께 인공지능(AI) 단백질 구조 예측 프로그램인 &#x27;로제타</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">뉴스1</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/421/0008386752" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news421,0008386752" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507230950_00000126/section/105?oid&#x3D;421&amp;aid&#x3D;0008386752" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">7</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/016/0002503527" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800010E_000000000000000002503527" data-imp-url="https://n.news.naver.com/mnews/article/016/0002503527" data-imp-index="5">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/016/2025/07/23/2503527.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="삼성전자, 갤럭시 워치 울트라에 ‘원 UI 8 워치’ 업데이트" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/016/0002503527" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800010E_000000000000000002503527" data-imp-url="https://n.news.naver.com/mnews/article/016/0002503527" data-imp-index="5">
# 							<strong class="sa_text_strong">삼성전자, 갤럭시 워치 울트라에 ‘원 UI 8 워치’ 업데이트</strong>
# 						</a>
# 						<div class="sa_text_lede">러닝코치·혈관 스트레스 등 건강 기능 지원 갤럭시 워치 티타늄 그레이 25일 출시 워치4 클래식까지 연내 적용 예정 [삼성전자 뉴스룸 갈무리] [헤럴드경제&#x3D;권제인 기자] 삼성전자가 기존 갤럭시 워치 울트라 모델을 대</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">헤럴드경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/016/0002503527" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news016,0002503527" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507230830_00000001/section/105?oid&#x3D;016&amp;aid&#x3D;0002503527" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">7</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/421/0008386582" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008386582" data-imp-url="https://n.news.naver.com/mnews/article/421/0008386582" data-imp-index="6">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/421/2025/07/23/8386582.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="무료 국제전화·로밍 혜택 강화…LGU+, 외국인 전용 요금제 출시" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/421/0008386582" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008386582" data-imp-url="https://n.news.naver.com/mnews/article/421/0008386582" data-imp-index="6">
# 							<strong class="sa_text_strong">무료 국제전화·로밍 혜택 강화…LGU+, 외국인 전용 요금제 출시</strong>
# 						</a>
# 						<div class="sa_text_lede">LG유플러스(032640)는 국내 거주 외국인 고객을 위해 무료 국제전화와 로밍 혜택을 포함한 7종의 &#x27;외국인 전용 프로모션 요금제&#x27;를 출시한다고 23일 밝혔다. 외국인 전용 요금제는 월 3만 7000원부터 8만 5</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">뉴스1</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/421/0008386582" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news421,0008386582" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507221820_00000207/section/105?oid&#x3D;421&amp;aid&#x3D;0008386582" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">18</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/092/0002382990" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800011E_000000000000000002382990" data-imp-url="https://n.news.naver.com/mnews/article/092/0002382990" data-imp-index="7">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/092/2025/07/22/2382990.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="&quot;韓 AI 인재 리셋 기회 왔다&quot;…이민 정책 변화에 美 중심 생태계 재편 가능성 ↑" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/092/0002382990" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800011E_000000000000000002382990" data-imp-url="https://n.news.naver.com/mnews/article/092/0002382990" data-imp-index="7">
# 							<strong class="sa_text_strong">&quot;韓 AI 인재 리셋 기회 왔다&quot;…이민 정책 변화에 美 중심 생태계 재편 가능성 ↑</strong>
# 						</a>
# 						<div class="sa_text_lede">전 세계에 인공지능(AI) 트렌드가 확산되며 인재 확보 경쟁이 치열해진 가운데 미국의 최근 변화로 우리나라뿐 아니라 유럽·일본·UAE 등 중견국들에게 기회가 열리고 있다는 분석이 나왔다. 이민 정책 변화, 공공 R</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">지디넷코리아</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/092/0002382990" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news092,0002382990" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507221040_00000195/section/105?oid&#x3D;092&amp;aid&#x3D;0002382990" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">8</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/031/0000950981" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D6_000000000000000000950981" data-imp-url="https://n.news.naver.com/mnews/article/031/0000950981" data-imp-index="8">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/031/2025/07/23/950981.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="메가존클라우드-UNDP, 베트남 지뢰제거·환경문제 해결 위한 AI 협력" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/031/0000950981" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D6_000000000000000000950981" data-imp-url="https://n.news.naver.com/mnews/article/031/0000950981" data-imp-index="8">
# 							<strong class="sa_text_strong">메가존클라우드-UNDP, 베트남 지뢰제거·환경문제 해결 위한 AI 협력</strong>
# 						</a>
# 						<div class="sa_text_lede">AI·클라우드 선도 기업 메가존클라우드는 최근 유엔개발계획(UNDP)과 ‘AI 기반 지속가능 사회 혁신과 지역사회 복지 증진을 위한 업무협력협약(MOU)’을 체결했다고 23일 밝혔다. 이번 협력을 통해 메가존클라우드</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">아이뉴스24</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/031/0000950981" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news031,0000950981" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202507230940_00001850/section/105?oid&#x3D;031&amp;aid&#x3D;0000950981" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">5</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 	</ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# 	<a href="#" class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON _NLOG_IMPRESSION_TRIGGER" data-target="_SECTION_HEADLINE_LIST_rf9ot" data-clk="clsmore">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# 	<div class="ss_head">
# 		<div class="ss_head_inner">
# 			<a href="https://news.naver.com/hotissue/main?sid1&#x3D;163&amp;cid&#x3D;2000113" class="ss_head_link" data-clk="sert">
# 				<span class="ss_head_go">연재보기</span>
# 				<h2 class="ss_head_topic">소부장반차장</h2>
# 			</a>
# 		</div>
# 	</div>
# 	<div class="ss_body">
# 		<ul class="ss_list">
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002201191?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002201191" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002201191?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="ydvct">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2025/07/23/2201191.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="헤일로, 초저전력 생성형 AI 칩 ‘Hailo-10H’ 출시" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002201191?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002201191" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002201191?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="ydvct">헤일로, 초저전력 생성형 AI 칩 ‘Hailo-10H’ 출시</a>
# 					<div class="ss_text_lede">이스라엘의 AI 반도체 스타트업 헤일로(Hailo)가 생성형 AI 성능을 엣지 디바이스에 구현할 수 있는 차세대 AI 칩 ‘Hailo-10H’를 22일(현지시간)공식 출시했다고 발표했다. 이 칩은 낮은 전력 소모로도</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002201191" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002201191" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002201184?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002201184" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002201184?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="jnnm6">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2025/07/23/2201184.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="&quot;AI 반도체 칩렛 잡는다&quot;…리벨리온·코아시아세미, 첨단 패키징 동맹" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002201184?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002201184" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002201184?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="jnnm6">&quot;AI 반도체 칩렛 잡는다&quot;…리벨리온·코아시아세미, 첨단 패키징 동맹</a>
# 					<div class="ss_text_lede">국내 AI 반도체 기업 리벨리온이 시스템 반도체 설계 전문기업 코아시아세미와 손잡고 데이터센터용 AI 칩렛 개발에 나선다. 칩렛은 고성능·고효율이 요구되는 인공지능(AI)·고성능컴퓨팅(HPC) 시장에서 주목받는 차세</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002201184" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002201184" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002201050?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002201050" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002201050?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="w9n6q">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2025/07/21/2201050.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="中향 AI 반도체 규제 완화에 웃는 &#x27;삼성전자&#x27;…메모리·파운드리 &#x27;쌍끌이&#x27; 기대감" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002201050?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002201050" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002201050?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="w9n6q">中향 AI 반도체 규제 완화에 웃는 &#x27;삼성전자&#x27;…메모리·파운드리 &#x27;쌍끌이&#x27; 기대감</a>
# 					<div class="ss_text_lede">미국 정부가 중국향 인공지능(AI) 반도체 수출 규제를 일부 완화할 조짐을 보이면서, 삼성전자가 뜻밖의 수혜를 입을 가능성이 제기되고 있다. HBM(고대역폭 메모리) 공급 확대와 파운드리 수주 반등이라는 &#x27;투트랙&#x27; </div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002201050" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002201050" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002200969?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002200969" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002200969?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="gtp1z">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2025/07/20/2200969.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="엔비디아 H20 中 수출 재개…韓 반도체 &#x27;기회·경고&#x27; 동시에" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002200969?type&#x3D;series&amp;cid&#x3D;2000113" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002200969" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002200969?type&#x3D;series&amp;cid&#x3D;2000113" data-imp-index="gtp1z">엔비디아 H20 中 수출 재개…韓 반도체 &#x27;기회·경고&#x27; 동시에</a>
# 					<div class="ss_text_lede">디지털데일리 소부장반차장 독자 여러분, 이번 주도 반차장이 반도체 업계의 중요한 이슈를 전해드립니다. &lt;반차장보고서&gt;에서는 이번 주에 놓쳐서는 안 되는 주요 뉴스들을 간결하게 풀어드리고 있습니다. 놓친 반도체 이슈를</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002200969" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002200969" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 		</ul>
# 	</div>
# </div>
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# 	<div class="ss_head">
# 		<div class="ss_head_inner">
# 			<a href="https://news.naver.com/hotissue/main?sid1&#x3D;163&amp;cid&#x3D;1087797" class="ss_head_link" data-clk="sert">
# 				<span class="ss_head_go">연재보기</span>
# 				<h2 class="ss_head_topic">코인브리핑</h2>
# 			</a>
# 		</div>
# 	</div>
# 	<div class="ss_body">
# 		<ul class="ss_list">
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005380976?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005380976" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005380976?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="26wrb">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/014/2025/07/23/5380976.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="日 스테이블코인 법제화 역설...&quot;과도한 규제가 혁신 발목&quot;" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005380976?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005380976" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005380976?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="26wrb">日 스테이블코인 법제화 역설...&quot;과도한 규제가 혁신 발목&quot;</a>
# 					<div class="ss_text_lede">미국보다 앞서 스테이블코인을 법제화한 일본이 시장 활성화에 어려움을 겪고 있다. 이른바 &#x27;규제 선제성과 시장 혁신 사이의 균형점&#x27;을 찾지 못한 결과, 법적 지위를 인정 받은 엔화 연동 스테이블코인은 &#x27;제로&#x27;인 상황이</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">파이낸셜뉴스</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/014/0005380976" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news014,0005380976" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005380817?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005380817" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005380817?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="8krj0">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/014/2025/07/22/5380817.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="&#x27;美 지니어스 액트&#x27; 다음은? 홍콩, 내달 스테이블코인 발행" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005380817?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005380817" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005380817?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="8krj0">&#x27;美 지니어스 액트&#x27; 다음은? 홍콩, 내달 스테이블코인 발행</a>
# 					<div class="ss_text_lede">국제 금융허브인 홍콩이 내달 1일부터 스테이블코인 발행을 허용한다. 가상자산에 엄격한 중국 본토와 달리 홍콩의 법정화폐 기반 스테이블코인(FRS) 발행자에 대한 라이선스를 마련하는 등 규율 명확성에 초점을 맞췄다. </div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">파이낸셜뉴스</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/014/0005380817" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news014,0005380817" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005380518?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005380518" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005380518?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="nynhh">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/014/2025/07/22/5380518.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="비트코인, 11만6000달러선 횡보…‘이더리움·XRP’ 강세" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005380518?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005380518" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005380518?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="nynhh">비트코인, 11만6000달러선 횡보…‘이더리움·XRP’ 강세</a>
# 					<div class="ss_text_lede">글로벌 가상자산 시가총액 1위 비트코인이 22일 11만6000달러선에서 횡보하고 있는 반면, 시총 2, 3위인 이더리움과 엑스알피(XRP, 리플)는 최근 일주일 동안 20%대 상승률을 보이고 있다. 글로벌 가상자산 </div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">파이낸셜뉴스</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/014/0005380518" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news014,0005380518" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/014/0005379843?type&#x3D;series&amp;cid&#x3D;1087797" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000FF_000000000000000005379843" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/014/0005379843?type&#x3D;series&amp;cid&#x3D;1087797" data-imp-index="9m2r1">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/014/2025/07/21/5379843.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="비트코인, ‘지니어스 법’ 통과 후 11만7000달러선 횡보" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# ...
# <div class="u_ft_inner">
# <footer role="contentinfo">
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.serviceall" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </span>
# </span>
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.guide" href="https://news.naver.com/ombudsman">서비스안내</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">고객센터</a>
# </span>
# </span>
# <span class="u_charge">
# <a class="u_charge_item" data-clk="fot.editor" href="https://news.naver.com/ombudsman/edit">기사배열 책임자 : 김수향</a>
# <span class="u_charge_item">청소년 보호 책임자 : 이정규</span>
# </span>
# <span class="u_copyright">
# 					이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 <br/>이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
# 				</span>
# <span class="u_naverlogo">
# <a class="u_naverlogo_a" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER</a>
# </span>
# </p>
# </footer>
# </div>
# </div>
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_DIALOG_WRAP" style="display: none;"></div>
# <script class="_MODAL_DIALOG_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_dialog_dimmed">
# 	<div class="nds_dialog_basic">
# 		<div class="nds_dialog_content">
# 			{{#isTextType}}
# 			<p class="nds_dialog_text">{{content.title}}</p>
# 			{{/isTextType}}
# 			{{#isTitleType}}
# 			<strong class="nds_dialog_title">
# 				<span class="nds_dialog_title_ellipsis">{{content.headTitle}}</span>
# 				{{content.title}}
# 			</strong>
# 			<p class="nds_dialog_description">{{content.description}}</p>
# 			{{/isTitleType}}
# 		</div>
# 		<div class="nds_dialog_button_area">
# 			<div class="nds_button_main_action as_layout_5_5">
# 				{{#isCancel}}
# 				<button type="button" class="nds_button_wide _MODAL_CANCEL"{{#content.clk.cancelClk}} data-clk="{{content.clk.cancelClk}}"{{/content.clk.cancelClk}}>
# 				{{content.cancelMessage}}
# 				</button>
# 				{{/isCancel}}
# 				<button type="button" class="nds_button_wide as_primary _MODAL_CONFIRM"{{#content.clk.confirmClk}} data-clk="{{content.clk.confirmClk}}"{{/content.clk.confirmClk}}>
# 				{{content.confirmMessage}}
# 				</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_TOAST" style="display: none;"></div>
# <script class="_MODAL_TOAST_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_popover_toast as_center">
# 	<div class="nds_toast_text_area">
# 		<div class="nds_toast_text_area"><span class="nds_toast_ellipsis_text"><strong>{{toastTitle}}</strong></span> {{toastMessage}}</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250717/library.min.js"></script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250717/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"105","name":"IT"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService",
# 					nlogEvt: {
# 						page_layout: window.layoutName
# 					}
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "105"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
#
# 				setTimeout(function() {
# 					$("._OPACITY_FADE_TO").fadeTo(50, 1);
# 				}, 3000);
# 			});
# 		</script>
# </body>
# </html>
#
# 44
# <class 'bs4.element.ResultSet'>
# 1 KT그룹, 수해 복구 성금 10억원 기탁 https://n.news.naver.com/mnews/article/018/0006071842
# 2 단통법 오늘 폐지…‘마이너스폰’ ‘페이백’ 가능 고객은 신난다 https://n.news.naver.com/mnews/article/021/0002724449
# 3 CJ ENM, 韓 엔터사 최초 사우디에 법인 설립 https://n.news.naver.com/mnews/article/009/0005529568
# 4 노벨화학상 숨은 주역…APEC 우수 신진연구자 상에 백민경 교수 https://n.news.naver.com/mnews/article/421/0008386752
# 5 삼성전자, 갤럭시 워치 울트라에 ‘원 UI 8 워치’ 업데이트 https://n.news.naver.com/mnews/article/016/0002503527
# 6 무료 국제전화·로밍 혜택 강화…LGU+, 외국인 전용 요금제 출시 https://n.news.naver.com/mnews/article/421/0008386582
# 7 "韓 AI 인재 리셋 기회 왔다"…이민 정책 변화에 美 중심 생태계 재편 가능성 ↑ https://n.news.naver.com/mnews/article/092/0002382990
# 8 메가존클라우드-UNDP, 베트남 지뢰제거·환경문제 해결 위한 AI 협력 https://n.news.naver.com/mnews/article/031/0000950981
# 9 [유미's 픽] "서울대생도 이공계 싫다"…'의대 공화국' 韓, 인재 부족에 AI 경쟁력 '위기' https://n.news.naver.com/mnews/article/092/0002383148
# 10 소버린 AI 시대, 잇따라 두각 드러내는 韓 모델…AI 3대 강국 청신호 https://n.news.naver.com/mnews/article/277/0005626676
# 11 "보조금 늘면 통신사 바꿀래요"…단통법 폐지 반기는 소비자들 https://n.news.naver.com/mnews/article/015/0005161548
# 12 자금 급한 일론 머스크 xAI…수익 없이 16조 더 빌린다 https://n.news.naver.com/mnews/article/092/0002383142
# 13 [이슈진단+] "내 폰에 도청장치?"…뜬금없는 이 광고·콘텐츠 왜 뜰까 https://n.news.naver.com/mnews/article/092/0002383137
# 14 민생 소비쿠폰 받으려다 '깜짝'…"절대 누르지 마라" 정체는 https://n.news.naver.com/mnews/article/243/0000081770
# 15 [100세건강] 오후에도 소변 거품 많으면 '이 질환'…정기 검사 권장 https://n.news.naver.com/mnews/article/421/0008386692
# 16 “폐수에 태양광 비췄더니” ‘그린 암모니아’만 쏙 뽑아냈다 https://n.news.naver.com/mnews/article/016/0002503623
# 17 KT, 독자 AI 파운데이션 모델 개발 출사표 https://n.news.naver.com/mnews/article/092/0002383131
# 18 [단독] 웹툰 '유일무이 로맨스' 영상화…네이버웹툰 IP 넓어진다 https://n.news.naver.com/mnews/article/138/0002201186
# 19 애플, iOS 26 베타 4 공개…‘리퀴드 글래스’ 강화·AI 뉴스 요약 기능 부활 [MOVIEW] https://n.news.naver.com/mnews/article/138/0002201181
# 20 문체부, 영화 관람 활성화 위해 6천원 할인권 총 450만 장 배포 https://n.news.naver.com/mnews/article/092/0002383122
# 21 “237만원 최신폰이 60만원” 하루 가격 문의 수십건…시끌벅적 휴대폰 시장 https://n.news.naver.com/mnews/article/016/0002503600
# 22 ‘10만살’ 원시별 주위서 뜨거운 응축…태양계 첫 탄생도 이랬을까 https://n.news.naver.com/mnews/article/028/0002757453
# 23 전성우 파인메딕스 대표 "日·中·美서 내시경기구 게임체인저 자신" https://n.news.naver.com/mnews/article/018/0006071822
# 24 BYD, 유럽 전기차 생산 전략 수정…헝가리 대신 튀르키예 가속 https://n.news.naver.com/mnews/article/092/0002383118
# 25 소비쿠폰 받으려다 '봉변'…공무원인 줄 알았더니 '바우처 사기' https://n.news.naver.com/mnews/article/015/0005161501
# 26 “영화 반값에 보세요”…문체부 '6000원 할인권' 450만장 배포 https://n.news.naver.com/mnews/article/030/0003334238
# 27 펩트론, 성조숙증·전립선암 '게임체인저' 예고… 판도 뒤집힐까 https://n.news.naver.com/mnews/article/018/0006071775
# 28 한국판 GPT 정예팀 3배수 압축…독자구축·서비스 이력 관건 https://n.news.naver.com/mnews/article/421/0008386507
# 29 오픈AI, 오라클과 ‘스타게이트’ 제휴 확대…“4.5GW 추가” https://n.news.naver.com/mnews/article/029/0002970240
# 30 "애플, 2027년 6개 새 아이폰 내놓는다…역대 최대 규모" https://n.news.naver.com/mnews/article/092/0002383107
# 31 [인터뷰] “AI 비서, 열 자식 안 부럽죠”...‘똑비’가 시니어 마음 얻는 법 https://n.news.naver.com/mnews/article/138/0002201167
# 32 NHN클라우드, 정부 GPU 사업 ‘연내 구축’ 차질…데이터센터 가동 ‘변수’로 https://n.news.naver.com/mnews/article/138/0002201166
# 33 비트코인 상승세, 12만 달러선 회복 https://n.news.naver.com/mnews/article/018/0006071698
# 34 크래프톤은 왜 K-AI에 도전했을까 https://n.news.naver.com/mnews/article/003/0013378970
# 35 [미장브리핑] S&P500 종가 사상 최고치…나스닥 7거래일만에 하락 https://n.news.naver.com/mnews/article/092/0002383102
# 36 디랩스게임즈 김재석 대표 "버스8, AI 게임계 로블록스 될 것" https://n.news.naver.com/mnews/article/001/0015523579
# 37 [IT썰]아마존, '음소거 안 하면 모든 소리 녹음하는' 스타트업 인수 https://n.news.naver.com/mnews/article/008/0005225498
# 38 반려동물 수술로 입원 앞뒀다면…"이것 꼭 준비해주세요"[펫카드] https://n.news.naver.com/mnews/article/421/0008386383
# 39 "AI로 막 만들면 수익 안 준다"…유튜브·메타 'AI 찌꺼기' 골치 https://n.news.naver.com/mnews/article/421/0008386382
# 40 WSJ 보도 반박…오픈AI “스타게이트, 5GW 돌파·10만 일자리 창출” https://n.news.naver.com/mnews/article/030/0003334216
# 41 트럼프 앞에서 700조 투자한댔는데…오픈AI 차질설 수습 잰걸음 https://n.news.naver.com/mnews/article/008/0005225494
# 42 기술만 베끼는 줄 알았더니…중국의 무서운 '전술' [AI 엑스파일] https://n.news.naver.com/mnews/article/015/0005161444
# 43 "AI 3대 강국 해볼 만하겠네"…소버린 AI 모델들 잇따른 낭보 https://n.news.naver.com/mnews/article/001/0015523522
# 44 유럽 R&D '군사력·우주' 중심 급변…'준회원' 한국에 불똥 튀나 https://n.news.naver.com/mnews/article/008/0005225492

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

# section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section):  #print_new(103,'생활/문화')
    sid = section_dict[section]
    url = f'https://news.naver.com/section/{sid}'
    print(f'{url} {section} 뉴스')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
    }

    # requests 의 get() 함수 호출하기
    res=requests.get(url, headers=req_header)
    print(res.status_code, res.ok)
    
    if (res.ok):
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        a_tags = soup.select("div.sa_text a[href*='mnews/article'].sa_text_title")
        print(len(a_tags))
        # <a> 태그 리스트 순회하기   
        for idx, a_tag in enumerate(a_tags,1):
            if a_tag.text:
                title = a_tag.text.strip() # 제목
                link = a_tag['href'] # 링크
                # print(len(title))
                print(f'{idx} {title} {link}')
    else:
        # 응답(response)이 Error 이면 status code 출력  
        print(f'Error Code = {res.status_code}')

# %%
print_news('생활/문화')
# Out:
# https://news.naver.com/section/103 생활/문화 뉴스
# 200 True
# 43
# 1 낮 최고 36도 '찜통 더위' 계속…강원·충북·경북 소나기(종합) https://n.news.naver.com/mnews/article/421/0008386309
# 2 고종이 美선교사에게 전한 ‘나전 삼층장’, 국가유산 된다 https://n.news.naver.com/mnews/article/016/0002503617
# 3 "영화 반값에 보세요"…문체부, '6000원 할인권' 450만장 배포 https://n.news.naver.com/mnews/article/015/0005161462
# 4 “상하차도 해봤다”…기아 PV5, ‘스포티지→카니발’ 마법 비결 https://n.news.naver.com/mnews/article/029/0002970234
# 5 나무가 AI로 친환경 기사 쓴다…현대차, '나무 특파원' 캠페인 https://n.news.naver.com/mnews/article/001/0015523955
# 6 한국GM 수해車 특별정비 서비스…車 교체시 최대 100만원 할인 https://n.news.naver.com/mnews/article/421/0008386480
# 7 대서, 폭염 확대·강화‥강한 소나기 주의[날씨] https://n.news.naver.com/mnews/article/214/0001438023
# 8 “몸에 좋은 줄 알았는데”… ‘이 음식’, 암 예방의 훼방꾼이었나? https://n.news.naver.com/mnews/article/346/0000094927
# 9 운동 한다고 먹고 싶은 건 다 먹었다간...내장 지방 쌓여 건강 위협 받아 https://n.news.naver.com/mnews/article/296/0000091500
# 10 BYD·테슬라 절반 수준… 현대차, 수직계열화 공 들이는 이유 https://n.news.naver.com/mnews/article/366/0001094816
# 11 달걀, “콜레스테롤 높이는 주범” 오명 벗었다… ‘이 음식’이 더 위험 https://n.news.naver.com/mnews/article/346/0000094926
# 12 "1000원에 극장에서 영화 보세요"…모레부터 6000원 할인권 발급 https://n.news.naver.com/mnews/article/015/0005161529
# 13 이 정도면 신이 물감통을 떨어뜨린 게 분명하다 [은퇴하고 산티아고] https://n.news.naver.com/mnews/article/047/0002482000
# 14 ‘반값 영화’ 정부 6천원 영화할인권 450만장 푼다 https://n.news.naver.com/mnews/article/021/0002724585
# 15 갑자기 오전 회의가 잡혔다... '눈치 비용'을 아십니까 https://n.news.naver.com/mnews/article/047/0002481999
# 16 [날씨] '찜통 더위' 오늘 경산 37℃...갈수록 더워진다 https://n.news.naver.com/mnews/article/052/0002223185
# 17 '민생회복 소비쿠폰' 받은 중학생이 하는 말 https://n.news.naver.com/mnews/article/047/0002481996
# 18 "근육 위한 배합 따져야… 단백질 보충제에 의료 현장 고민 담았다" https://n.news.naver.com/mnews/article/346/0000094921
# 19 [날씨] 밤낮 무더위, 갈수록 심해져‥동쪽 곳곳 소나기 https://n.news.naver.com/mnews/article/214/0001438188
# 20 '업그레이드 신제품 출시' 프로티아 주가 ↑…'FDA와 타입A 미팅' HLB ↓[바이오맥... https://n.news.naver.com/mnews/article/018/0006071833
# 21 "당뇨병·신장질환 함께 앓는 환자 늘어… 혈액·소변검사 주기적으로 받아야" https://n.news.naver.com/mnews/article/346/0000094918
# 22 '좀비딸' 개봉에 네이버 원작 웹툰 몰아보기 9배↑…완결 5년 만에 재조명 https://n.news.naver.com/mnews/article/011/0004512442
# 23 3500만원 들여 '젊어지는 수술' 받은 60대女…"두 가지 크게 후회" [헬스톡] https://n.news.naver.com/mnews/article/014/0005381060
# 24 ‘램시마’ 영국 점유율 71%… 현지 맞춤형 전략 성과 https://n.news.naver.com/mnews/article/020/0003649819
# 25 ‘깜빡깜빡’거리는 기억력… 포스파티딜세린으로 붙잡자 https://n.news.naver.com/mnews/article/020/0003649818
# 26 척추 수술 후에도 통증 지속된다면… 비수술적 ‘추간공확장술’ 고려를 https://n.news.naver.com/mnews/article/020/0003649813
# 27 성조숙증 진단은 타이밍 싸움… 여아 7∼8세, 남아 8∼9세가 ‘골든타임’ https://n.news.naver.com/mnews/article/020/0003649812
# 28 에어컨 빵빵하게, 환기도 안하고 틀면 ‘냉방병’ 위험[홍은심 기자의 긴가민가 질환시그널] https://n.news.naver.com/mnews/article/020/0003649811
# 29 “습성 황반변성, 투여 간격 20주로 늘어난 고용량 치료제로 부담 낮춰” https://n.news.naver.com/mnews/article/020/0003649805
# 30 사망률 2위 간암… ‘이중면역항암요법’으로 장기생존 문 열었다 https://n.news.naver.com/mnews/article/020/0003649804
# 31 신경 눌림 방치 땐 ‘꼬부랑 노인’… 척추관협착증, 재활도 중요 https://n.news.naver.com/mnews/article/020/0003649803
# 32 [시니어그룹] 대사증후군 검사를 받고 당장 결심한 것 https://n.news.naver.com/mnews/article/047/0002481983
# 33 [날씨] 오늘 낮 서울 33℃·경산 37℃...주 후반 폭염 더 심해져 https://n.news.naver.com/mnews/article/052/0002223171
# 34 코로나에 걸렸었든 아니든 간에...“팬데믹 때문에 우리의 뇌 빨리 늙었다” https://n.news.naver.com/mnews/article/296/0000091499
# 35 ‘위고비 대항마‘ 마운자로 韓상륙 임박…반격 나선 K바이오 https://n.news.naver.com/mnews/article/018/0006071772
# 36 "점심에 커피 먹지 말라고요?" 오후에 마시는 커피, 뇌 어떤 영향 주길래 [건강잇슈] https://n.news.naver.com/mnews/article/014/0005381037
# 37 '시속 80km' 전기 스쿠터 화제…그런데 가격이? https://n.news.naver.com/mnews/article/092/0002383112
# 38 하와이 왕복 60만 원·10㎝ 늘린 좌석... 저가항공 에어프레미아 타보니 https://n.news.naver.com/mnews/article/469/0000877540
# 39 다음 주 중복 메뉴 고민 중이라면? 요즘 뜨는 '이것' 어때요 [쿠킹] https://n.news.naver.com/mnews/article/025/0003457026
# 40 비행기·호텔 에약해놨는데 "콘서트 취소"...티켓값 환불로 되겠나 https://n.news.naver.com/mnews/article/277/0005626575
# 41 "조수석은 뺄게요"…레고처럼 맘대로 짜맞추는 기아 PV5 등장 https://n.news.naver.com/mnews/article/277/0005626569
# 42 "대통령이 직접 관광 챙기면 안돼" vs "강력한 정책 실행 위해 꼭 필요" https://n.news.naver.com/mnews/article/018/0006071739
# 43 [아미랑] 암 환자, 비타민D ‘이렇게’ 보충을 https://n.news.naver.com/mnews/article/346/0000094915

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=802840&no=87&week=tue',
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/802840/87/20250718123431_47d28a75a7d4ead679960095c3caa04c_IMAG01_36.jpg',
    'https://image-comic.pstatic.net/webtoon/802840/87/20250718123431_47d28a75a7d4ead679960095c3caa04c_IMAG01_34.jpg',
    'https://image-comic.pstatic.net/webtoon/802840/87/20250718123431_47d28a75a7d4ead679960095c3caa04c_IMAG01_56.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.ok, res.status_code)
    if res.ok:
        # binary 응답 데이터 가져오기
        img_data = res.content
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to {file_name}({len(img_data):,} bytes)')
            file.write(img_data)
# Out:
# True 200
# Writing to 20250718123431_47d28a75a7d4ead679960095c3caa04c_IMAG01_36.jpg(233,063 bytes)
# True 200
# Writing to 20250718123431_47d28a75a7d4ead679960095c3caa04c_IMAG01_34.jpg(198,593 bytes)
# True 200
# Writing to 20250718123431_47d28a75a7d4ead679960095c3caa04c_IMAG01_56.jpg(260,322 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os


webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=776668&no=214&week=thu'
req_header = {
    'referer': webtoon_url,
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
res = requests.get(webtoon_url)
print(res.status_code)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    # print(len(soup.select("img[src$='.jpg']")))
    # print(len(soup.select("img[src^='https://image-comic.pstatic.net/webtoon/776668/214']")))
    print(len(soup.select("img[src*='IMAG01']"))) # 일치
    # img src file명을 저장할 list 선언
    img_url_list = list()
    img_tags = soup.select("img[src*='IMAG01']") #  Resultset [Tag, Tag,]
    for img_tag in img_tags: # img_tag의 타입은 Tag <img>
        img_url = img_tag['src']
        img_url_list.append(img_url)
    # print(len(img_url_list), img_url_list[0:2])

    # img 디렉토리가 없으면 생성하기
    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for jpg_url in img_url_list:  # test 시에는 [0:n] 붙이기
        res = requests.get(jpg_url, headers=req_header)
        if res.ok:
            # binary data 추출하기
            img_data = res.content
            # img/xxx.jpg 디랙토리명과 jpg파일명을 join
            dir_name = os.path.join(imgdir_name, os.path.basename(jpg_url))
            with open(dir_name, 'wb') as file:
                print(f'Writing to {dir_name}({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error Code = {res.status_code}')
# Out:
# 200
# 75
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_1.jpg(78,467 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_2.jpg(223,913 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_3.jpg(175,349 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_4.jpg(175,549 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_5.jpg(161,479 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_6.jpg(118,510 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_7.jpg(137,034 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_8.jpg(227,215 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_9.jpg(191,854 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_10.jpg(324,590 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_11.jpg(142,383 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_12.jpg(207,229 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_13.jpg(179,439 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_14.jpg(186,584 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_15.jpg(159,902 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_16.jpg(131,143 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_17.jpg(160,410 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_18.jpg(73,435 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_19.jpg(135,889 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_20.jpg(134,964 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_21.jpg(144,279 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_22.jpg(132,943 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_23.jpg(72,886 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_24.jpg(61,788 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_25.jpg(130,738 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_26.jpg(89,848 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_27.jpg(109,916 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_28.jpg(129,414 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_29.jpg(357,762 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_30.jpg(273,110 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_31.jpg(215,037 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_32.jpg(176,487 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_33.jpg(130,633 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_34.jpg(155,181 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_35.jpg(148,836 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_36.jpg(143,862 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_37.jpg(104,359 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_38.jpg(156,824 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_39.jpg(180,388 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_40.jpg(109,891 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_41.jpg(196,865 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_42.jpg(176,305 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_43.jpg(180,892 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_44.jpg(197,351 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_45.jpg(137,020 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_46.jpg(122,812 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_47.jpg(139,102 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_48.jpg(192,550 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_49.jpg(234,270 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_50.jpg(72,851 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_51.jpg(139,890 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_52.jpg(117,883 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_53.jpg(117,491 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_54.jpg(398,301 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_55.jpg(221,674 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_56.jpg(314,926 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_57.jpg(258,394 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_58.jpg(105,388 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_59.jpg(407,161 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_60.jpg(169,243 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_61.jpg(228,549 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_62.jpg(198,821 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_63.jpg(177,915 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_64.jpg(195,787 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_65.jpg(133,888 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_66.jpg(128,458 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_67.jpg(139,992 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_68.jpg(70,766 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_69.jpg(167,605 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_70.jpg(195,423 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_71.jpg(125,764 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_72.jpg(97,096 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_73.jpg(81,644 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_74.jpg(150,734 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_75.jpg(26,012 bytes)

# %% [markdown]
# ### 리팩토링 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=776668&no=214&week=thu'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 url 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path}({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')
# Out:
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_1.jpg(78,467 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_2.jpg(223,913 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_3.jpg(175,349 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_4.jpg(175,549 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_5.jpg(161,479 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_6.jpg(118,510 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_7.jpg(137,034 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_8.jpg(227,215 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_9.jpg(191,854 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_10.jpg(324,590 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_11.jpg(142,383 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_12.jpg(207,229 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_13.jpg(179,439 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_14.jpg(186,584 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_15.jpg(159,902 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_16.jpg(131,143 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_17.jpg(160,410 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_18.jpg(73,435 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_19.jpg(135,889 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_20.jpg(134,964 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_21.jpg(144,279 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_22.jpg(132,943 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_23.jpg(72,886 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_24.jpg(61,788 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_25.jpg(130,738 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_26.jpg(89,848 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_27.jpg(109,916 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_28.jpg(129,414 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_29.jpg(357,762 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_30.jpg(273,110 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_31.jpg(215,037 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_32.jpg(176,487 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_33.jpg(130,633 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_34.jpg(155,181 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_35.jpg(148,836 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_36.jpg(143,862 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_37.jpg(104,359 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_38.jpg(156,824 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_39.jpg(180,388 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_40.jpg(109,891 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_41.jpg(196,865 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_42.jpg(176,305 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_43.jpg(180,892 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_44.jpg(197,351 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_45.jpg(137,020 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_46.jpg(122,812 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_47.jpg(139,102 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_48.jpg(192,550 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_49.jpg(234,270 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_50.jpg(72,851 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_51.jpg(139,890 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_52.jpg(117,883 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_53.jpg(117,491 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_54.jpg(398,301 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_55.jpg(221,674 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_56.jpg(314,926 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_57.jpg(258,394 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_58.jpg(105,388 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_59.jpg(407,161 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_60.jpg(169,243 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_61.jpg(228,549 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_62.jpg(198,821 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_63.jpg(177,915 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_64.jpg(195,787 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_65.jpg(133,888 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_66.jpg(128,458 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_67.jpg(139,992 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_68.jpg(70,766 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_69.jpg(167,605 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_70.jpg(195,423 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_71.jpg(125,764 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_72.jpg(97,096 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_73.jpg(81,644 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_74.jpg(150,734 bytes)
# Writing to img\20250611161305_74590bdcdf21755775589c02f4e063e6_IMAG01_75.jpg(26,012 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('f1.jpg', 'rb'),
    'img2': open('f2.jpg', 'rb'),
    'img3': open('f3.jpg', 'rb')
}
# print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res =  requests.post(url, files=upload_files)
# print(res.status_code)
print(type(res.json()))
# print(res.json())
print(res.json()['files']['img1'])
# Out:
# <class 'dict'>
# data:application/octet-stream;base64,...

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청
import urllib.request

client_id = "sZwSDgOlDDCFZmNUaw9M" # 개발자센터에서 발급받은 Client ID 값
client_secret = "YMGdyfrghy" # 개발자센터에서 발급받은 Client Secret 값

code = "0"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code
#Request 객체생성
request = urllib.request.Request(url)
#요청헤더 설정
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
#서버에 request 전달
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"key":"mmSlcQAnHgxGffta"}

# %%
# 캡차 이미지 요청
import urllib.request

client_id = "sZwSDgOlDDCFZmNUaw9M" # 개발자센터에서 발급받은 Client ID 값
client_secret = "YMGdyfrghy" # 개발자센터에서 발급받은 Client Secret 값
key = "5PzQH8Gy8Kv8FbSK" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# 캡차 이미지 저장

# %%
#  사용자 입력값 검증 요청
import urllib.request

client_id = "sZwSDgOlDDCFZmNUaw9M" # 개발자센터에서 발급받은 Client ID 값
client_secret = "YMGdyfrghy" # 개발자센터에서 발급받은 Client Secret 값
code = "1"
key = "vUdD0YsIr9ALrt7b"
value = "7T91"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code + "&key=" + key + "&value=" + value
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
import os
from dotenv import load_dotenv
import requests

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET
key = "5PzQH8Gy8Kv8FbSK"
# os.getenv("NAVER_CAPTCHA_KEY") # .env 파일의 NAVER_CAPTCHA_KEY

# 사용자 입력값
code = "1"
value = "834DN9"  # 실제 사용시 사용자 입력값으로 대체 필요

# URL 구성
# query string key1=value1&key2=value2
url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}&key={key}&value={value}"

# 요청 헤더
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# 요청 보내기
try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # 4xx, 5xx 오류 발생시 예외 발생
    
    # 응답 처리
    print(response.text)
    
except requests.exceptions.RequestException as e:
    print(f"Error occurred: {e}")
    print(f"Status Code: {response.status_code if 'response' in locals() else 'N/A'}")
# Out:
# {"result":true,"responseTime":313.22}

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
from pprint import pprint
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'date'  # sim
}

url = 'https://openapi.naver.com/v1/search/blog.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']
print(type(res.json()))
# pprint(res.json()['items'])
print(len(items_data), type(items_data), type(items_data[0]))
pprint(items_data[0])

#[{},{},{}] 
# [] - 100 개의 데이터, {title:'',link:''} - 1개의 블로그 글 데이터
# Out:
# <class 'dict'>
# 100 <class 'list'> <class 'dict'>

# %%
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
items_list = list()
item_list = []
for item in items_data:
    # print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])
    item_list.append(item['postdate'])

    items_list.append(item_list)
    item_list = []

print(items_list) #[[],[],[]]

# 'data/nhnblog.txt' 파일 생성하기
with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
# Out:
# [['대전<b>파이썬</b>학원 단계별 코딩 실무 학습 과정', '오롯이 여행, 마음먹기 나름 :)', '그래서 대전<b>파이썬</b>학원을 알아보기로 했죠. 아무 데서나 할 순 없고 커리큘럼을 단계별 실무 위주로... 기초 코딩: 프로그래밍 언어 이 과정은 대전<b>파이썬</b>학원에 처음 오는 입문자들이 프로그래밍 언어를... ', 'blog.naver.com/she_op', 'https://blog.naver.com/she_op/223881011131', '20250528'], ['강남 AI특강, <b>파이썬</b>으로 시작하는 실전 수업', '퍼플피치', '결국 <b>파이썬</b>으로 수렴되더라고요. 문법도 어렵지 않고, 무엇보다 인공지능이나 빅데이터 같은 분야에서 거의 필수처럼 쓰인다고 하니까요. 이 강의의 커리큘럼을 살펴봤을 때 <b>파이썬</b> 중심으로 구성되어 있다는... ', 'blog.naver.com/purplepeach81', 'https://blog.naver.com/purplepeach81/223902982714', '20250618'], ['<b>파이썬</b>으로 주식 분석', '해머', '<b>파이썬</b>으로 주식 분석을 해보고 싶은 분들 제가 <b>파이썬</b>을 사용해서 주식 데이터를 수집하고 분석해본 경험을 바탕으로 정리해볼게요. 초보자도 이해할 수 있도록 전체적인 흐름부터 사용한 라이브러리... ', 'blog.naver.com/sn525v', 'https://blog.naver.com/sn525v/223924507846', '20250709'], ['대전<b>파이썬</b>학원 실전에 적용 가능한 실무 수업', '▶ 제이의 맛있는 세상 ◀', '되면서 <b>파이썬</b>과 같은 언어를 기반으로 한 학습의 필요성이 더욱 커지고 있답니다. 이러한 흐름 속에서 기초부터 실무 활용까지 단계적으로 학습할 수 있는 곳을 찾는다면 대전<b>파이썬</b>학원이 좋은 선택이 될 수... ', 'blog.naver.com/xshinerx', 'https://blog.naver.com/xshinerx/223920684811', '20250704'], ['<b>파이썬</b>전문가 자격증 종류 및 효율적인 취득방법', '멜잉로그 : 현 영어강사 블로그', '<b>파이썬</b>전문가 자격증 종류 및 효율적인 취득방법 <b>파이썬</b>은 요즘 다양한 분야에서 널리 사용되는 프로그래밍 언어로, 데이터 분석, 웹 개발, 인공지능 등에서 중요한 역할을 하고 있습니다. 저는 원래... ', 'blog.naver.com/mellybird', 'https://blog.naver.com/mellybird/223842981098', '20250422'], ['빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기', '묘한 교육 연구소', '빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기 빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기 빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기 빅데이터분석기사 취득자의 후기를 소개합니다.... ', 'blog.naver.com/blackhole_chinese', 'https://blog.naver.com/blackhole_chinese/223900117182', '20250615'], ['<b>파이썬</b>전문가 자격증 학습방법 취득후기', 'ALICEMADE-앨리스가 만들어가는 세상', '<b>파이썬</b>전문가 자격증 학습방법 취득후기 요즘 IT 분야에 대한 관심이 점점 더 높아지며 앞으로 어떤... 그러던 중 남들에게 제가 알고 있는 기술을 알려주고 싶은 마음에 <b>파이썬</b>전문가 자격증에 도전했고 나만의... ', 'blog.naver.com/bbobbny', 'https://blog.naver.com/bbobbny/223842932148', '20250422'], ['<b>파이썬</b>자격증 종류 취업 분야 및 공부 후기', '세 아이와 함께 성장하는 곳', '<b>파이썬</b>자격증 종류 취업 분야 및 공부 후기 공부하신 분의 후기를 바탕으로 작성되었음을... 결심하고 처음으로 도전한 것은 <b>파이썬</b>자격증이었어요. 입문용 언어라 가장 저에게 적합했는데요. 같은... ', 'blog.naver.com/kang6902', 'https://blog.naver.com/kang6902/223863482199', '20250512'], ['macOS <b>파이썬</b> 프로그래밍 PYTHON 개발 환경 구축 방법', '짜루의 이것저것 리뷰', 'macOS <b>파이썬</b> 프로그래밍 PYTHON 개발 환경 구축 방법 요즘 AI 자동화가 대세다. n8n 같은 AI 기반 워크플로 자동화 도구만으로도 충분하지만, <b>파이썬</b> 프로그래밍까지 더해진다면 훨씬 더 강력해진다.... ', 'blog.naver.com/skdaksdptn', 'https://blog.naver.com/skdaksdptn/223932219095', '20250713'], ['<b>파이썬</b>전문가 자격증 종류 체계적인 취득방법 및 학습과정', '하영목(출간작가)의 블로그', '<b>파이썬</b>전문가 자격증 종류 체계적인 취득방법 및 학습과정 요즘은 취업하려면 코딩은 필수인 거... 오늘 <b>파이썬</b>전문가 자격증 종류 체계적인 취득방법 및 학습과정을 가져와 보았습니다! <b>파이썬</b> 자격증 종류... ', 'blog.naver.com/career4ukr', 'https://blog.naver.com/career4ukr/223842923010', '20250422'], ['<b>파이썬</b>학원, 전공 대비 여름방학 특강', '지혜를 여는 부엉이상점', "그런데 요즘은 '<b>파이썬</b>'이 대세라는데요 <b>파이썬</b>은 왜 전공자에게 필수 언어가 되었을까? 프로그래밍 언어는 수업이 많지만, 최근 몇 년 사이 전공자들이 입을 모아 &quot;<b>파이썬</b>은 무조건 해둬야 해&quot;라고 말하는... ", 'blog.naver.com/smgong00', 'https://blog.naver.com/smgong00/223903445166', '20250618'], ['[<b>파이썬</b> 배우기] 직장인 일잘러... 시작한 <b>파이썬</b> 독학하기... ', '싱글맘 바니의 스토리 블로그', "<b>파이썬</b>, <b>파이썬</b>... 우연히 들은 CHAT GPT 강의에서 업무 자동화 프로세스 라는 단어가 내 귀에 딱 꽂혔다. 나는 매일 출근하며 영업일을 보는 직장인이라 고객사들에게 늘 전화가 온다. '이 제품은 단가가 얼마?... ", 'blog.naver.com/singlemom_bonnie', 'https://blog.naver.com/singlemom_bonnie/223911004817', '20250625'], ['<b>파이썬</b> 기초 독학 - 이 책으로 비전공자도 가능', '˚✧₊❁⁎솨의봄날⁎⁺˳❁✧༚', '최근에 제가 AI관련 공부를 시작하게 되었는데요 거기서 나오는게 <b>파이썬</b>이더라구요 <b>파이썬</b> AI와 코딩의 가장 기초가 되더라구요 코딩, 어렵고 복잡한 언어라고만 생각했던 그 시절 그런데 요즘은 일상 속에서... ', 'blog.naver.com/sohwa91', 'https://blog.naver.com/sohwa91/223904016899', '20250618'], ['AI 인공지능 프로젝트 <b>파이썬</b> 프로젝트 입문자를 위한 책 추천', '엔돌슨의 IT이야기', '카테고리 없음 AI 인공지능 프로젝트 <b>파이썬</b> 프로젝트 입문자를 위한 책 추천 by 엔돌슨 2025. 6. 13. AI 인공지능 프로젝트 <b>파이썬</b> 프로젝트 입문자를 위한 책 추천 AI와 프로그래밍이 더 이상 전문가만의... ', 'https://ndolson.com/', 'https://ndolson.com/531581', '20250613'], ['<b>파이썬</b> 자격증 시험 종류 및 취득과정', '화닝의 일본어+교육 교실', '오늘은 <b>파이썬</b> 자격증 시험 종류 및 취득과정에 대해서 자세 ...
